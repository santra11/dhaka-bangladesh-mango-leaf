# %%
# Import the following libraries
import os
import random
import shutil

import numpy as np
from PIL import Image, ImageFilter
from matplotlib import pyplot as plt

# %%
train_dir = 'Train'
test_dir = 'Test'
#valid_dir = 'Validation'

# %%
# Import the Path class
from pathlib import Path  

train_dir = Path(train_dir)
test_dir = Path(test_dir)
#valid_dir = Path(valid_dir)

# %%
# Define the hyperparamenter

train_size = 3299
test_size = 379
img_height = 224
img_width = 224
n_classes = 8
batch_size = 32
n_epochs = 50

# %%
# The generator 
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Standardize the data
datagen = ImageDataGenerator(rescale=1.0 / 255)

# Create batches of data from each set train, test and validation)
train_ds = datagen.flow_from_directory(directory=train_dir,
                                               target_size=(img_height,
                                                            img_width),
                                               color_mode='rgb',
                                               class_mode='categorical',
                                               batch_size=batch_size)

test_ds = datagen.flow_from_directory(directory=test_dir,
                                      target_size=(img_height, img_width),
                                      color_mode='rgb',
                                      class_mode='categorical',
                                      batch_size=batch_size)
# Out:
# Found 3299 images belonging to 8 classes.
# Found 379 images belonging to 8 classes.

# %%
# What Labels correspond to what categories
labels = {value: key for key, value in train_ds.class_indices.items()}

print("Label encoding for classes present in the train dataset\n")
for key, value in labels.items():
    print(f"{key} : {value}")
# Out:
# Label encoding for classes present in the train dataset
#
# 0 : Anthracnose
# 1 : Bacterial Canker
# 2 : Cutting Weevil
# 3 : Die Back
# 4 : Gall Midge
# 5 : Healthy
# 6 : Powdery Mildew
# 7 : Scooty Mould

# %% [markdown]
# ### How to deal with the train dataset which is clearly imbalanced

# %%
# Define the class weight function balance the train dataset
from sklearn.utils.class_weight import compute_class_weight

class_weights = compute_class_weight(class_weight = "balanced", 
                                     classes= np.unique(train_ds.labels), 
                                     y= train_ds.labels)

# %%
class_weights = dict(zip(np.unique(train_ds.labels), class_weights))
class_weights
# Out:
# {0: 0.9634929906542056,
#  1: 0.9501728110599078,
#  2: 1.8744318181818183,
#  3: 0.943649885583524,
#  4: 0.9545717592592593,
#  5: 0.9163888888888889,
#  6: 0.9204799107142857,
#  7: 0.9163888888888889}

# %%
for image_batch, labels_batch in train_ds:
    print(image_batch.shape)
    break
# Out:
# (32, 224, 224, 3)

# %%
fig, ax = plt.subplots(nrows=2, ncols=4, figsize=(10, 10))
idx = 0

for i in range(2):
    for j in range(4):
        label = labels[np.argmax(train_ds[0][1][idx])]
        ax[i, j].set_title(f"True Label: {label}")
        ax[i, j].imshow(train_ds[0][0][idx][:, :, :])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Sample Train Images", fontsize=21)
plt.show()

# %%
print('Number of samples: ',train_ds.samples)
print('Number of classes: ',len(train_ds.class_indices))
print('Number of samples per class:', int(train_ds.samples/len(train_ds.class_indices)))
# Out:
# Number of samples:  3299
# Number of classes:  8
# Number of samples per class: 412

# %%
# Import all the tensorflow libraries as required for the model

from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, BatchNormalization, Conv2D, Dense, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.models import Model
from tensorflow.keras.models import load_model

# %% [markdown]
# ### We create a CNN model from scratch

# %%
def create_model():
    model = Sequential([
        Conv2D(128, kernel_size=(5, 5), padding='same', input_shape=(img_width, img_height, 3)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(64, kernel_size=(3, 3), padding='same', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Conv2D(32, kernel_size=(3, 3), padding='same', kernel_regularizer=l2(0.00005)),
        Activation('relu'),
        MaxPooling2D(pool_size=(2, 2)),
        BatchNormalization(),
        
        Flatten(),
        
        Dense(256, activation='relu'),
        Dropout(0.5),
        Dense(n_classes, activation='softmax')
    ])
    
    return model

# %%
model = create_model()
# Out:
# 2023-09-11 19:09:02.317584: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 224, 224, 128)     9728
#
#  activation (Activation)     (None, 224, 224, 128)     0
#
#  max_pooling2d (MaxPooling2D  (None, 112, 112, 128)    0
#  )
#
#  batch_normalization (BatchN  (None, 112, 112, 128)    512
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 112, 112, 64)      73792
#
#  activation_1 (Activation)   (None, 112, 112, 64)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 56, 56, 64)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 56, 56, 64)       256
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 56, 56, 32)        18464
#
#  activation_2 (Activation)   (None, 56, 56, 32)        0
#
#  max_pooling2d_2 (MaxPooling  (None, 28, 28, 32)       0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 28, 28, 32)       128
#  hNormalization)
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 256)               6422784
#
#  dropout (Dropout)           (None, 256)               0
#
#  dense_1 (Dense)             (None, 8)                 2056
#
# =================================================================
# Total params: 6,527,720
# Trainable params: 6,527,272
# Non-trainable params: 448
# _________________________________________________________________

# %%
# Utilize the Adam Optimizers
opt = keras.optimizers.Adam(learning_rate=1e-5)
model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])  

# Use Early Stopping
es=EarlyStopping(monitor='val_loss',mode='min',verbose=1,patience=10)

# %%
history = model.fit(
    train_ds, class_weight=class_weights,
    epochs=n_epochs,
    validation_data=test_ds,  # Use the test dataset for validation
    steps_per_epoch=train_size // batch_size,  # Use integer division
    validation_steps=test_size // batch_size,  # Use integer division
    callbacks=[es])
# Out:
# Epoch 1/50
# 103/103 [==============================] - 611s 6s/step - loss: 1.5308 - accuracy: 0.4634 - val_loss: 2.1996 - val_accuracy: 0.1506
# Epoch 2/50
# 103/103 [==============================] - 614s 6s/step - loss: 0.7801 - accuracy: 0.7080 - val_loss: 2.9561 - val_accuracy: 0.1250
# Epoch 3/50
# 103/103 [==============================] - 744s 7s/step - loss: 0.5406 - accuracy: 0.7998 - val_loss: 3.2719 - val_accuracy: 0.1420
# Epoch 4/50
# 103/103 [==============================] - 672s 7s/step - loss: 0.4115 - accuracy: 0.8540 - val_loss: 2.3412 - val_accuracy: 0.3097
# Epoch 5/50
# 103/103 [==============================] - 604s 6s/step - loss: 0.3320 - accuracy: 0.8812 - val_loss: 1.0070 - val_accuracy: 0.6250
# Epoch 6/50
# 103/103 [==============================] - 678s 7s/step - loss: 0.2682 - accuracy: 0.9097 - val_loss: 0.4541 - val_accuracy: 0.8466
# Epoch 7/50
# 103/103 [==============================] - 747s 7s/step - loss: 0.2195 - accuracy: 0.9308 - val_loss: 0.3270 - val_accuracy: 0.8778
# Epoch 8/50
# 103/103 [==============================] - 734s 7s/step - loss: 0.1705 - accuracy: 0.9449 - val_loss: 0.3221 - val_accuracy: 0.8778
# Epoch 9/50
# 103/103 [==============================] - 740s 7s/step - loss: 0.1518 - accuracy: 0.9510 - val_loss: 0.2842 - val_accuracy: 0.8864
# Epoch 10/50
# 103/103 [==============================] - 699s 7s/step - loss: 0.1488 - accuracy: 0.9547 - val_loss: 0.2717 - val_accuracy: 0.9062
# Epoch 11/50
# 103/103 [==============================] - 606s 6s/step - loss: 0.1286 - accuracy: 0.9602 - val_loss: 0.2506 - val_accuracy: 0.9034
# Epoch 12/50
# 103/103 [==============================] - 632s 6s/step - loss: 0.0994 - accuracy: 0.9709 - val_loss: 0.2718 - val_accuracy: 0.9062
# Epoch 13/50
# 103/103 [==============================] - 732s 7s/step - loss: 0.0963 - accuracy: 0.9709 - val_loss: 0.2559 - val_accuracy: 0.9034
# Epoch 14/50
# 103/103 [==============================] - 729s 7s/step - loss: 0.0858 - accuracy: 0.9746 - val_loss: 0.2237 - val_accuracy: 0.9148
# Epoch 15/50
# 103/103 [==============================] - 730s 7s/step - loss: 0.0830 - accuracy: 0.9749 - val_loss: 0.2439 - val_accuracy: 0.9119
# Epoch 16/50
# 103/103 [==============================] - 642s 6s/step - loss: 0.0714 - accuracy: 0.9773 - val_loss: 0.2312 - val_accuracy: 0.9261
# Epoch 17/50
# 103/103 [==============================] - 600s 6s/step - loss: 0.0620 - accuracy: 0.9850 - val_loss: 0.2306 - val_accuracy: 0.9318
# Epoch 18/50
# 103/103 [==============================] - 661s 6s/step - loss: 0.0677 - accuracy: 0.9810 - val_loss: 0.2765 - val_accuracy: 0.8892
# Epoch 19/50
# 103/103 [==============================] - 745s 7s/step - loss: 0.0562 - accuracy: 0.9882 - val_loss: 0.2228 - val_accuracy: 0.9347
# Epoch 20/50
# 103/103 [==============================] - 733s 7s/step - loss: 0.0515 - accuracy: 0.9871 - val_loss: 0.2215 - val_accuracy: 0.9290
# Epoch 21/50
# 103/103 [==============================] - 733s 7s/step - loss: 0.0496 - accuracy: 0.9868 - val_loss: 0.2168 - val_accuracy: 0.9233
# Epoch 22/50
# 103/103 [==============================] - 727s 7s/step - loss: 0.0455 - accuracy: 0.9890 - val_loss: 0.2231 - val_accuracy: 0.9148
# Epoch 23/50
# 103/103 [==============================] - 745s 7s/step - loss: 0.0421 - accuracy: 0.9902 - val_loss: 0.2131 - val_accuracy: 0.9233
# Epoch 24/50
# 103/103 [==============================] - 735s 7s/step - loss: 0.0398 - accuracy: 0.9914 - val_loss: 0.2193 - val_accuracy: 0.9347
# Epoch 25/50
# 103/103 [==============================] - 726s 7s/step - loss: 0.0384 - accuracy: 0.9920 - val_loss: 0.2024 - val_accuracy: 0.9318
# Epoch 26/50
# 103/103 [==============================] - 736s 7s/step - loss: 0.0385 - accuracy: 0.9923 - val_loss: 0.2532 - val_accuracy: 0.9176
# Epoch 27/50
# 103/103 [==============================] - 730s 7s/step - loss: 0.0358 - accuracy: 0.9927 - val_loss: 0.1861 - val_accuracy: 0.9432
# Epoch 28/50
# 103/103 [==============================] - 733s 7s/step - loss: 0.0303 - accuracy: 0.9948 - val_loss: 0.2171 - val_accuracy: 0.9233
# Epoch 29/50
# 103/103 [==============================] - 727s 7s/step - loss: 0.0289 - accuracy: 0.9948 - val_loss: 0.2464 - val_accuracy: 0.9290
# Epoch 30/50
# 103/103 [==============================] - 733s 7s/step - loss: 0.0330 - accuracy: 0.9942 - val_loss: 0.1764 - val_accuracy: 0.9318
# Epoch 31/50
# 103/103 [==============================] - 729s 7s/step - loss: 0.0266 - accuracy: 0.9960 - val_loss: 0.1620 - val_accuracy: 0.9375
# Epoch 32/50
# 103/103 [==============================] - 732s 7s/step - loss: 0.0257 - accuracy: 0.9945 - val_loss: 0.1918 - val_accuracy: 0.9460
# Epoch 33/50
# 103/103 [==============================] - 731s 7s/step - loss: 0.0287 - accuracy: 0.9954 - val_loss: 0.2156 - val_accuracy: 0.9318
# Epoch 34/50
# 103/103 [==============================] - 728s 7s/step - loss: 0.0339 - accuracy: 0.9933 - val_loss: 0.2962 - val_accuracy: 0.9034
# Epoch 35/50
# 103/103 [==============================] - 728s 7s/step - loss: 0.0283 - accuracy: 0.9957 - val_loss: 0.1992 - val_accuracy: 0.9176
# Epoch 36/50
# 103/103 [==============================] - 725s 7s/step - loss: 0.0243 - accuracy: 0.9954 - val_loss: 0.2216 - val_accuracy: 0.9233
# Epoch 37/50
# 103/103 [==============================] - 732s 7s/step - loss: 0.0236 - accuracy: 0.9963 - val_loss: 0.2254 - val_accuracy: 0.9261
# Epoch 38/50
# 103/103 [==============================] - 675s 7s/step - loss: 0.0200 - accuracy: 0.9976 - val_loss: 0.1910 - val_accuracy: 0.9347
# Epoch 39/50
# 103/103 [==============================] - 608s 6s/step - loss: 0.0206 - accuracy: 0.9966 - val_loss: 0.2170 - val_accuracy: 0.9233
# Epoch 40/50
# 103/103 [==============================] - 681s 7s/step - loss: 0.0196 - accuracy: 0.9972 - val_loss: 0.2236 - val_accuracy: 0.9432
# Epoch 41/50
# 103/103 [==============================] - 730s 7s/step - loss: 0.0223 - accuracy: 0.9945 - val_loss: 0.2411 - val_accuracy: 0.9261
# Epoch 41: early stopping

# %% [markdown]
# ### Plot the learning curves

# %%
# Create a figure with two subplots, one for accuracy and one for loss
fig, axes = plt.subplots(1, 2, figsize=(8, 10))

# Plot accuracy
axes[0].plot(history.history['accuracy'], label='Train acc', color='blue')
axes[0].plot(history.history['val_accuracy'], label='Val acc', color='orange')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].set_title('Accuracy')
axes[0].legend()

# Plot loss
axes[1].plot(history.history['loss'], label='Train loss', color='blue')
axes[1].plot(history.history['val_loss'], label='Val loss', color='orange')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].set_title('Loss')
axes[1].legend()

plt.tight_layout()  # Ensure that subplots don't overlap
plt.show()

# %%
test_loss, test_accuracy = model.evaluate(test_ds)
# Out:
# 12/12 [==============================] - 21s 2s/step - loss: 0.2338 - accuracy: 0.9261

# %%
print(f"Test Loss:     {test_loss}")
print(f"Test Accuracy: {test_accuracy}")
# Out:
# Test Loss:     0.23378002643585205
# Test Accuracy: 0.9261213541030884

# %% [markdown]
# ### Plot the confusion matrix

# %%
preds = model.predict(test_ds, batch_size=batch_size)

y_true = test_ds.classes
y_pred=np.argmax(preds,axis=1)

# %%
from sklearn.metrics import confusion_matrix

# Create the confusion matrix
cm = confusion_matrix(test_ds.classes, y_pred)

# %%
import seaborn as sns 
group_counts = ["{0:0.0f}".format(value) for value in cm.flatten()]
group_percentages = ["{0:.2%}".format(value) for value in cm.flatten()/np.sum(cm)]
box_labels = [f"{v1}\n({v2})" for v1, v2 in zip(group_counts, group_percentages)]
box_labels = np.asarray(box_labels).reshape(8, 8)

plt.figure(figsize = (8, 8))
sns.heatmap(cm, xticklabels=labels.values(), yticklabels=labels.values(),
           cmap="YlGnBu", fmt="", annot=box_labels)
plt.xlabel('Predicted Classes')
plt.ylabel('True Classes')
plt.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=4, figsize=(12, 10))
idx = 0

for i in range(2):
    for j in range(4):
        predicted_label = labels[np.argmax(preds[idx])]
        ax[i, j].set_title(f"True Label: {label} \n Predicted Label: {predicted_label}")
        ax[i, j].imshow(test_ds[0][0][idx])
        ax[i, j].axis("off")
        idx += 1

plt.tight_layout()
plt.suptitle("Test Dataset Predictions", fontsize=20)
plt.show()

# %%
from sklearn.metrics import classification_report

print(classification_report(y_true, y_pred, target_names=labels.values()))
# Out:
#                   precision    recall  f1-score   support
#
#      Anthracnose       0.12      0.12      0.12        50
# Bacterial Canker       0.18      0.18      0.18        49
#   Cutting Weevil       0.10      0.10      0.10        30
#         Die Back       0.12      0.12      0.12        50
#       Gall Midge       0.19      0.16      0.17        50
#          Healthy       0.15      0.14      0.14        50
#   Powdery Mildew       0.11      0.10      0.10        50
#     Scooty Mould       0.17      0.22      0.19        50
#
#         accuracy                           0.15       379
#        macro avg       0.14      0.14      0.14       379
#     weighted avg       0.14      0.15      0.14       379

# %%
# Save the model
model.save('CNNSCRATCH.h5')
